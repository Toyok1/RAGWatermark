# %%
from transformers import AutoTokenizer
import json
import os
#tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2-xl") #BPE tokenizer
#tokenizer = AutoTokenizer.from_pretrained("bert-base-cased") #WordPiece tokenizer
tokenizer = AutoTokenizer.from_pretrained("xlnet-base-cased") #Unigram tokenizer

real_path = "./distribution/real/part_"
tokenized_path = "./distribution/tokenized/part_"

def walk_directory(directory):
    l = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".json"):
                l.append(os.path.join(root, file))
    return l
#divide l into 10 equal parts
def divide_into_parts(l, n):
    return [l[i::n] for i in range(n)]

# %%
def create_article_list(file):
    #print(f"Creating article list from {file}")
    articles = []
        # Load the JSON file
    with open(file, "r") as fl:
        f = json.load(fl)
        articles.append(f["original_doc"])
        articles.append(f['articles']['gpt4o']['article'])
        articles.append(f['articles']['claude3.5sonnet']['article'])
        articles.append(f['articles']['llama3.1-405b']['article'])
        articles.append(f['articles']['qwen1.5-110b']['article'])
    #print(f"Found {len(articles)} articles in {file}")
    return articles

def conservative_tokenize(path):
    token_distribution = {}
    a = path.split('/real')
    b = a[0] + "/tokenized" + a[1]
    #on the first pass, tokenize the file. Save the tokenized file in another directory with a .tok.json extension. If the file already exists, load it instead.
    output_path = b.replace(".json", ".tok.json")
    if os.path.exists(output_path):
        print(f"Loading existing token distribution from {output_path}")
        # Load the existing token distribution
        with open(output_path, "r") as f:
            token_distribution = json.load(f)
    else:
        print(f"Tokenizing {path} and saving to {output_path}")
        # Create the directory if it doesn't exist
        for article in create_article_list(path):
            # Tokenize the article
            #print(f"Tokenizing article: {article[:50]}...")
            article = article.strip()
            article = article.lower()
            data = tokenizer(article, return_tensors="pt", truncation=True, max_length=512)#tokenizer.model_max_length)
        for token_id in data["input_ids"][0]:
                token = tokenizer.decode(token_id.item())
                if token not in token_distribution:
                    token_distribution[token] = 0
                token_distribution[token] += 1
        with open(output_path, "w") as fd:
            json.dump(token_distribution, fd, indent=4)
    return token_distribution

# %%
def create_distribution(piecelist):
    final_token_distribution = {}
    for file in piecelist:
        print(f"Processing file: {file}")
        token_distribution = conservative_tokenize(file)
        # Merge the token distributions
        for token, count in token_distribution.items():
            if token not in final_token_distribution:
                final_token_distribution[token] = 0
            final_token_distribution[token] += count
    sorted_distribution = dict(sorted(final_token_distribution.items(), key=lambda item: item[1], reverse=True))
    output_file = "./json_files/token_distribution.json"
    #if the file already exists, update it
    if os.path.exists(output_file):
        with open(output_file, "r") as f:
            existing_distribution = json.load(f)
        for token, count in sorted_distribution.items():
            if token in existing_distribution:
                existing_distribution[token] += count
            else:
                existing_distribution[token] = count
        sorted_distribution = dict(sorted(existing_distribution.items(), key=lambda item: item[1], reverse=True))
    os.remove(output_file) if os.path.exists(output_file) else None
    # Save the final token distribution to a JSON file
    with open(output_file, "w") as f:
        json.dump(sorted_distribution, f, indent=4)

# %%
'''jsonfiles = walk_directory("./farad")
parts = divide_into_parts(jsonfiles, 10)
#move each part into its separate folder
for i, part in enumerate(parts):
    os.makedirs(f"./distribution/part_{i}", exist_ok=True)
    #put all files in the part into the folder
    for file in part:
        os.rename(file, f"./distribution/part_{i}/{os.path.basename(file)}")'''
# Out:
# 'jsonfiles = walk_directory("./farad")\nparts = divide_into_parts(jsonfiles, 10)\n#move each part into its separate folder\nfor i, part in enumerate(parts):\n    os.makedirs(f"./distribution/part_{i}", exist_ok=True)\n    #put all files in the part into the folder\n    for file in part:\n        os.rename(file, f"./distribution/part_{i}/{os.path.basename(file)}")'

# %%
#create a cycle to process each part

for i in range(0,10):
    piece = walk_directory(f"{real_path}{i}")
    token_distribution = create_distribution(piece)
# Out:
# Processing file: ./distribution/real/part_0\0000.json
# Tokenizing ./distribution/real/part_0\0000.json and saving to ./distribution/tokenized/part_0\0000.tok.json
# Processing file: ./distribution/real/part_0\0010.json
# Tokenizing ./distribution/real/part_0\0010.json and saving to ./distribution/tokenized/part_0\0010.tok.json
# Processing file: ./distribution/real/part_0\0020.json
# Tokenizing ./distribution/real/part_0\0020.json and saving to ./distribution/tokenized/part_0\0020.tok.json
# Processing file: ./distribution/real/part_0\0030.json
# Tokenizing ./distribution/real/part_0\0030.json and saving to ./distribution/tokenized/part_0\0030.tok.json
# Processing file: ./distribution/real/part_0\0040.json
# Tokenizing ./distribution/real/part_0\0040.json and saving to ./distribution/tokenized/part_0\0040.tok.json
# Processing file: ./distribution/real/part_0\0050.json
# Tokenizing ./distribution/real/part_0\0050.json and saving to ./distribution/tokenized/part_0\0050.tok.json
# Processing file: ./distribution/real/part_0\0060.json
# Tokenizing ./distribution/real/part_0\0060.json and saving to ./distribution/tokenized/part_0\0060.tok.json
# Processing file: ./distribution/real/part_0\0070.json
# Tokenizing ./distribution/real/part_0\0070.json and saving to ./distribution/tokenized/part_0\0070.tok.json
# Processing file: ./distribution/real/part_0\0080.json
# Tokenizing ./distribution/real/part_0\0080.json and saving to ./distribution/tokenized/part_0\0080.tok.json
# Processing file: ./distribution/real/part_0\0090.json
# Tokenizing ./distribution/real/part_0\0090.json and saving to ./distribution/tokenized/part_0\0090.tok.json
# Processing file: ./distribution/real/part_0\0100.json
# Tokenizing ./distribution/real/part_0\0100.json and saving to ./distribution/tokenized/part_0\0100.tok.json
# Processing file: ./distribution/real/part_0\0110.json
# Tokenizing ./distribution/real/part_0\0110.json and saving to ./distribution/tokenized/part_0\0110.tok.json
# Processing file: ./distribution/real/part_0\0120.json
# Tokenizing ./distribution/real/part_0\0120.json and saving to ./distribution/tokenized/part_0\0120.tok.json
# Processing file: ./distribution/real/part_0\0130.json
# Tokenizing ./distribution/real/part_0\0130.json and saving to ./distribution/tokenized/part_0\0130.tok.json
# Processing file: ./distribution/real/part_0\0140.json
# Tokenizing ./distribution/real/part_0\0140.json and saving to ./distribution/tokenized/part_0\0140.tok.json
# Processing file: ./distribution/real/part_0\0150.json
# Tokenizing ./distribution/real/part_0\0150.json and saving to ./distribution/tokenized/part_0\0150.tok.json
# Processing file: ./distribution/real/part_0\0160.json
# Tokenizing ./distribution/real/part_0\0160.json and saving to ./distribution/tokenized/part_0\0160.tok.json
# Processing file: ./distribution/real/part_0\0170.json
# Tokenizing ./distribution/real/part_0\0170.json and saving to ./distribution/tokenized/part_0\0170.tok.json
# Processing file: ./distribution/real/part_0\0180.json
# Tokenizing ./distribution/real/part_0\0180.json and saving to ./distribution/tokenized/part_0\0180.tok.json
# Processing file: ./distribution/real/part_0\0190.json
# Tokenizing ./distribution/real/part_0\0190.json and saving to ./distribution/tokenized/part_0\0190.tok.json
# Processing file: ./distribution/real/part_0\0200.json
# Tokenizing ./distribution/real/part_0\0200.json and saving to ./distribution/tokenized/part_0\0200.tok.json
# Processing file: ./distribution/real/part_0\0210.json
# Tokenizing ./distribution/real/part_0\0210.json and saving to ./distribution/tokenized/part_0\0210.tok.json
# Processing file: ./distribution/real/part_0\0220.json
# Tokenizing ./distribution/real/part_0\0220.json and saving to ./distribution/tokenized/part_0\0220.tok.json
# Processing file: ./distribution/real/part_0\0230.json
# Tokenizing ./distribution/real/part_0\0230.json and saving to ./distribution/tokenized/part_0\0230.tok.json
# Processing file: ./distribution/real/part_0\0240.json
# Tokenizing ./distribution/real/part_0\0240.json and saving to ./distribution/tokenized/part_0\0240.tok.json
# Processing file: ./distribution/real/part_0\0250.json
# Tokenizing ./distribution/real/part_0\0250.json and saving to ./distribution/tokenized/part_0\0250.tok.json
# Processing file: ./distribution/real/part_0\0260.json
# Tokenizing ./distribution/real/part_0\0260.json and saving to ./distribution/tokenized/part_0\0260.tok.json
# Processing file: ./distribution/real/part_0\0270.json
# Tokenizing ./distribution/real/part_0\0270.json and saving to ./distribution/tokenized/part_0\0270.tok.json
# Processing file: ./distribution/real/part_0\0280.json
# Tokenizing ./distribution/real/part_0\0280.json and saving to ./distribution/tokenized/part_0\0280.tok.json
# Processing file: ./distribution/real/part_0\0290.json
# Tokenizing ./distribution/real/part_0\0290.json and saving to ./distribution/tokenized/part_0\0290.tok.json
# Processing file: ./distribution/real/part_0\0300.json
# Tokenizing ./distribution/real/part_0\0300.json and saving to ./distribution/tokenized/part_0\0300.tok.json
# Processing file: ./distribution/real/part_0\0310.json
# Tokenizing ./distribution/real/part_0\0310.json and saving to ./distribution/tokenized/part_0\0310.tok.json
# Processing file: ./distribution/real/part_0\0320.json
# Tokenizing ./distribution/real/part_0\0320.json and saving to ./distribution/tokenized/part_0\0320.tok.json
# Processing file: ./distribution/real/part_0\0330.json
# Tokenizing ./distribution/real/part_0\0330.json and saving to ./distribution/tokenized/part_0\0330.tok.json
# Processing file: ./distribution/real/part_0\0340.json
# Tokenizing ./distribution/real/part_0\0340.json and saving to ./distribution/tokenized/part_0\0340.tok.json
# Processing file: ./distribution/real/part_0\0350.json
# Tokenizing ./distribution/real/part_0\0350.json and saving to ./distribution/tokenized/part_0\0350.tok.json
# Processing file: ./distribution/real/part_0\0360.json
# Tokenizing ./distribution/real/part_0\0360.json and saving to ./distribution/tokenized/part_0\0360.tok.json
# Processing file: ./distribution/real/part_0\0370.json
# Tokenizing ./distribution/real/part_0\0370.json and saving to ./distribution/tokenized/part_0\0370.tok.json
# Processing file: ./distribution/real/part_0\0380.json
# Tokenizing ./distribution/real/part_0\0380.json and saving to ./distribution/tokenized/part_0\0380.tok.json
# Processing file: ./distribution/real/part_0\0390.json
# Tokenizing ./distribution/real/part_0\0390.json and saving to ./distribution/tokenized/part_0\0390.tok.json
# Processing file: ./distribution/real/part_0\0400.json
# Tokenizing ./distribution/real/part_0\0400.json and saving to ./distribution/tokenized/part_0\0400.tok.json
# Processing file: ./distribution/real/part_0\0410.json
# Tokenizing ./distribution/real/part_0\0410.json and saving to ./distribution/tokenized/part_0\0410.tok.json
# Processing file: ./distribution/real/part_0\0420.json
# Tokenizing ./distribution/real/part_0\0420.json and saving to ./distribution/tokenized/part_0\0420.tok.json
# Processing file: ./distribution/real/part_0\0430.json
# Tokenizing ./distribution/real/part_0\0430.json and saving to ./distribution/tokenized/part_0\0430.tok.json
# Processing file: ./distribution/real/part_0\0440.json
# Tokenizing ./distribution/real/part_0\0440.json and saving to ./distribution/tokenized/part_0\0440.tok.json
# Processing file: ./distribution/real/part_0\0450.json
# Tokenizing ./distribution/real/part_0\0450.json and saving to ./distribution/tokenized/part_0\0450.tok.json
# Processing file: ./distribution/real/part_0\0460.json
# Tokenizing ./distribution/real/part_0\0460.json and saving to ./distribution/tokenized/part_0\0460.tok.json
# Processing file: ./distribution/real/part_0\0470.json
# Tokenizing ./distribution/real/part_0\0470.json and saving to ./distribution/tokenized/part_0\0470.tok.json
# Processing file: ./distribution/real/part_0\0480.json
# Tokenizing ./distribution/real/part_0\0480.json and saving to ./distribution/tokenized/part_0\0480.tok.json
# Processing file: ./distribution/real/part_0\0490.json
# Tokenizing ./distribution/real/part_0\0490.json and saving to ./distribution/tokenized/part_0\0490.tok.json
# Processing file: ./distribution/real/part_0\0500.json
# Tokenizing ./distribution/real/part_0\0500.json and saving to ./distribution/tokenized/part_0\0500.tok.json
# Processing file: ./distribution/real/part_0\0510.json
# Tokenizing ./distribution/real/part_0\0510.json and saving to ./distribution/tokenized/part_0\0510.tok.json
# Processing file: ./distribution/real/part_0\0520.json
# Tokenizing ./distribution/real/part_0\0520.json and saving to ./distribution/tokenized/part_0\0520.tok.json
# Processing file: ./distribution/real/part_0\0530.json
# Tokenizing ./distribution/real/part_0\0530.json and saving to ./distribution/tokenized/part_0\0530.tok.json
# Processing file: ./distribution/real/part_0\0540.json
# Tokenizing ./distribution/real/part_0\0540.json and saving to ./distribution/tokenized/part_0\0540.tok.json
# Processing file: ./distribution/real/part_0\0550.json
# Tokenizing ./distribution/real/part_0\0550.json and saving to ./distribution/tokenized/part_0\0550.tok.json
# Processing file: ./distribution/real/part_0\0560.json
# Tokenizing ./distribution/real/part_0\0560.json and saving to ./distribution/tokenized/part_0\0560.tok.json
# Processing file: ./distribution/real/part_0\0570.json
# Tokenizing ./distribution/real/part_0\0570.json and saving to ./distribution/tokenized/part_0\0570.tok.json
# Processing file: ./distribution/real/part_0\0580.json
# Tokenizing ./distribution/real/part_0\0580.json and saving to ./distribution/tokenized/part_0\0580.tok.json
# Processing file: ./distribution/real/part_0\0590.json
# Tokenizing ./distribution/real/part_0\0590.json and saving to ./distribution/tokenized/part_0\0590.tok.json
# Processing file: ./distribution/real/part_0\0600.json
# Tokenizing ./distribution/real/part_0\0600.json and saving to ./distribution/tokenized/part_0\0600.tok.json
# Processing file: ./distribution/real/part_0\0610.json
# Tokenizing ./distribution/real/part_0\0610.json and saving to ./distribution/tokenized/part_0\0610.tok.json
# Processing file: ./distribution/real/part_0\0620.json
# Tokenizing ./distribution/real/part_0\0620.json and saving to ./distribution/tokenized/part_0\0620.tok.json
# Processing file: ./distribution/real/part_0\0630.json
# Tokenizing ./distribution/real/part_0\0630.json and saving to ./distribution/tokenized/part_0\0630.tok.json
# Processing file: ./distribution/real/part_0\0640.json
# Tokenizing ./distribution/real/part_0\0640.json and saving to ./distribution/tokenized/part_0\0640.tok.json
# Processing file: ./distribution/real/part_0\0650.json
# Tokenizing ./distribution/real/part_0\0650.json and saving to ./distribution/tokenized/part_0\0650.tok.json
# Processing file: ./distribution/real/part_0\0660.json
# Tokenizing ./distribution/real/part_0\0660.json and saving to ./distribution/tokenized/part_0\0660.tok.json
# Processing file: ./distribution/real/part_0\0670.json
# Tokenizing ./distribution/real/part_0\0670.json and saving to ./distribution/tokenized/part_0\0670.tok.json
# Processing file: ./distribution/real/part_0\0680.json
# Tokenizing ./distribution/real/part_0\0680.json and saving to ./distribution/tokenized/part_0\0680.tok.json
# Processing file: ./distribution/real/part_0\0690.json
# Tokenizing ./distribution/real/part_0\0690.json and saving to ./distribution/tokenized/part_0\0690.tok.json
# Processing file: ./distribution/real/part_0\0700.json
# Tokenizing ./distribution/real/part_0\0700.json and saving to ./distribution/tokenized/part_0\0700.tok.json
# Processing file: ./distribution/real/part_0\0710.json
# Tokenizing ./distribution/real/part_0\0710.json and saving to ./distribution/tokenized/part_0\0710.tok.json
# Processing file: ./distribution/real/part_0\0720.json
# Tokenizing ./distribution/real/part_0\0720.json and saving to ./distribution/tokenized/part_0\0720.tok.json
# Processing file: ./distribution/real/part_0\0730.json
# Tokenizing ./distribution/real/part_0\0730.json and saving to ./distribution/tokenized/part_0\0730.tok.json
# Processing file: ./distribution/real/part_0\0740.json
# Tokenizing ./distribution/real/part_0\0740.json and saving to ./distribution/tokenized/part_0\0740.tok.json
# Processing file: ./distribution/real/part_0\0750.json
# Tokenizing ./distribution/real/part_0\0750.json and saving to ./distribution/tokenized/part_0\0750.tok.json
# Processing file: ./distribution/real/part_0\0760.json
# Tokenizing ./distribution/real/part_0\0760.json and saving to ./distribution/tokenized/part_0\0760.tok.json
# Processing file: ./distribution/real/part_0\0770.json
# Tokenizing ./distribution/real/part_0\0770.json and saving to ./distribution/tokenized/part_0\0770.tok.json
# Processing file: ./distribution/real/part_0\0780.json
# Tokenizing ./distribution/real/part_0\0780.json and saving to ./distribution/tokenized/part_0\0780.tok.json
# Processing file: ./distribution/real/part_0\0790.json
# Tokenizing ./distribution/real/part_0\0790.json and saving to ./distribution/tokenized/part_0\0790.tok.json
# Processing file: ./distribution/real/part_0\0800.json
# Tokenizing ./distribution/real/part_0\0800.json and saving to ./distribution/tokenized/part_0\0800.tok.json
# Processing file: ./distribution/real/part_0\0810.json
# Tokenizing ./distribution/real/part_0\0810.json and saving to ./distribution/tokenized/part_0\0810.tok.json
# Processing file: ./distribution/real/part_0\0820.json
# Tokenizing ./distribution/real/part_0\0820.json and saving to ./distribution/tokenized/part_0\0820.tok.json
# Processing file: ./distribution/real/part_0\0830.json
# Tokenizing ./distribution/real/part_0\0830.json and saving to ./distribution/tokenized/part_0\0830.tok.json
# Processing file: ./distribution/real/part_0\0840.json
# Tokenizing ./distribution/real/part_0\0840.json and saving to ./distribution/tokenized/part_0\0840.tok.json
# Processing file: ./distribution/real/part_0\0850.json
# Tokenizing ./distribution/real/part_0\0850.json and saving to ./distribution/tokenized/part_0\0850.tok.json
# Processing file: ./distribution/real/part_0\0860.json
# Tokenizing ./distribution/real/part_0\0860.json and saving to ./distribution/tokenized/part_0\0860.tok.json
# Processing file: ./distribution/real/part_0\0870.json
# Tokenizing ./distribution/real/part_0\0870.json and saving to ./distribution/tokenized/part_0\0870.tok.json
# Processing file: ./distribution/real/part_0\0880.json
# Tokenizing ./distribution/real/part_0\0880.json and saving to ./distribution/tokenized/part_0\0880.tok.json
# Processing file: ./distribution/real/part_0\0890.json
# Tokenizing ./distribution/real/part_0\0890.json and saving to ./distribution/tokenized/part_0\0890.tok.json
# Processing file: ./distribution/real/part_0\0900.json
# Tokenizing ./distribution/real/part_0\0900.json and saving to ./distribution/tokenized/part_0\0900.tok.json
# Processing file: ./distribution/real/part_0\0910.json
# Tokenizing ./distribution/real/part_0\0910.json and saving to ./distribution/tokenized/part_0\0910.tok.json
# Processing file: ./distribution/real/part_0\0920.json
# Tokenizing ./distribution/real/part_0\0920.json and saving to ./distribution/tokenized/part_0\0920.tok.json
# Processing file: ./distribution/real/part_0\0930.json
# Tokenizing ./distribution/real/part_0\0930.json and saving to ./distribution/tokenized/part_0\0930.tok.json
# Processing file: ./distribution/real/part_0\0940.json
# Tokenizing ./distribution/real/part_0\0940.json and saving to ./distribution/tokenized/part_0\0940.tok.json
# Processing file: ./distribution/real/part_0\0950.json
# Tokenizing ./distribution/real/part_0\0950.json and saving to ./distribution/tokenized/part_0\0950.tok.json
# Processing file: ./distribution/real/part_0\0960.json
# Tokenizing ./distribution/real/part_0\0960.json and saving to ./distribution/tokenized/part_0\0960.tok.json
# Processing file: ./distribution/real/part_0\0970.json
# Tokenizing ./distribution/real/part_0\0970.json and saving to ./distribution/tokenized/part_0\0970.tok.json
# Processing file: ./distribution/real/part_0\0980.json
# Tokenizing ./distribution/real/part_0\0980.json and saving to ./distribution/tokenized/part_0\0980.tok.json
# Processing file: ./distribution/real/part_0\0990.json
# Tokenizing ./distribution/real/part_0\0990.json and saving to ./distribution/tokenized/part_0\0990.tok.json
# Processing file: ./distribution/real/part_0\1000.json
# Tokenizing ./distribution/real/part_0\1000.json and saving to ./distribution/tokenized/part_0\1000.tok.json
# Processing file: ./distribution/real/part_0\1010.json
# Tokenizing ./distribution/real/part_0\1010.json and saving to ./distribution/tokenized/part_0\1010.tok.json
# Processing file: ./distribution/real/part_0\1020.json
# Tokenizing ./distribution/real/part_0\1020.json and saving to ./distribution/tokenized/part_0\1020.tok.json
# Processing file: ./distribution/real/part_0\1030.json
# Tokenizing ./distribution/real/part_0\1030.json and saving to ./distribution/tokenized/part_0\1030.tok.json
# Processing file: ./distribution/real/part_0\1040.json
# Tokenizing ./distribution/real/part_0\1040.json and saving to ./distribution/tokenized/part_0\1040.tok.json
# Processing file: ./distribution/real/part_0\1050.json
# Tokenizing ./distribution/real/part_0\1050.json and saving to ./distribution/tokenized/part_0\1050.tok.json
# Processing file: ./distribution/real/part_0\1060.json
# Tokenizing ./distribution/real/part_0\1060.json and saving to ./distribution/tokenized/part_0\1060.tok.json
# Processing file: ./distribution/real/part_0\1070.json
# Tokenizing ./distribution/real/part_0\1070.json and saving to ./distribution/tokenized/part_0\1070.tok.json
# Processing file: ./distribution/real/part_0\1080.json
# Tokenizing ./distribution/real/part_0\1080.json and saving to ./distribution/tokenized/part_0\1080.tok.json
# Processing file: ./distribution/real/part_0\1090.json
# Tokenizing ./distribution/real/part_0\1090.json and saving to ./distribution/tokenized/part_0\1090.tok.json
# Processing file: ./distribution/real/part_0\1100.json
# Tokenizing ./distribution/real/part_0\1100.json and saving to ./distribution/tokenized/part_0\1100.tok.json
# Processing file: ./distribution/real/part_0\1110.json
# Tokenizing ./distribution/real/part_0\1110.json and saving to ./distribution/tokenized/part_0\1110.tok.json
# Processing file: ./distribution/real/part_0\1120.json
# Tokenizing ./distribution/real/part_0\1120.json and saving to ./distribution/tokenized/part_0\1120.tok.json
# Processing file: ./distribution/real/part_0\1130.json
# Tokenizing ./distribution/real/part_0\1130.json and saving to ./distribution/tokenized/part_0\1130.tok.json
# Processing file: ./distribution/real/part_0\1140.json
# Tokenizing ./distribution/real/part_0\1140.json and saving to ./distribution/tokenized/part_0\1140.tok.json
# Processing file: ./distribution/real/part_0\1150.json
# Tokenizing ./distribution/real/part_0\1150.json and saving to ./distribution/tokenized/part_0\1150.tok.json
# Processing file: ./distribution/real/part_0\1160.json
# Tokenizing ./distribution/real/part_0\1160.json and saving to ./distribution/tokenized/part_0\1160.tok.json
# Processing file: ./distribution/real/part_0\1170.json
# Tokenizing ./distribution/real/part_0\1170.json and saving to ./distribution/tokenized/part_0\1170.tok.json
# Processing file: ./distribution/real/part_0\1180.json
# Tokenizing ./distribution/real/part_0\1180.json and saving to ./distribution/tokenized/part_0\1180.tok.json
# Processing file: ./distribution/real/part_0\1190.json
# Tokenizing ./distribution/real/part_0\1190.json and saving to ./distribution/tokenized/part_0\1190.tok.json
# Processing file: ./distribution/real/part_0\1200.json
# Tokenizing ./distribution/real/part_0\1200.json and saving to ./distribution/tokenized/part_0\1200.tok.json
# Processing file: ./distribution/real/part_0\1210.json
# Tokenizing ./distribution/real/part_0\1210.json and saving to ./distribution/tokenized/part_0\1210.tok.json
# Processing file: ./distribution/real/part_0\1220.json
# Tokenizing ./distribution/real/part_0\1220.json and saving to ./distribution/tokenized/part_0\1220.tok.json
# Processing file: ./distribution/real/part_0\1230.json
# Tokenizing ./distribution/real/part_0\1230.json and saving to ./distribution/tokenized/part_0\1230.tok.json
# Processing file: ./distribution/real/part_0\1240.json
# Tokenizing ./distribution/real/part_0\1240.json and saving to ./distribution/tokenized/part_0\1240.tok.json
# Processing file: ./distribution/real/part_0\1250.json
# Tokenizing ./distribution/real/part_0\1250.json and saving to ./distribution/tokenized/part_0\1250.tok.json
# Processing file: ./distribution/real/part_0\1260.json
# Tokenizing ./distribution/real/part_0\1260.json and saving to ./distribution/tokenized/part_0\1260.tok.json
# Processing file: ./distribution/real/part_0\1270.json
# Tokenizing ./distribution/real/part_0\1270.json and saving to ./distribution/tokenized/part_0\1270.tok.json
# Processing file: ./distribution/real/part_0\1280.json
# Tokenizing ./distribution/real/part_0\1280.json and saving to ./distribution/tokenized/part_0\1280.tok.json
# Processing file: ./distribution/real/part_0\1290.json
# Tokenizing ./distribution/real/part_0\1290.json and saving to ./distribution/tokenized/part_0\1290.tok.json
# Processing file: ./distribution/real/part_0\1300.json
# Tokenizing ./distribution/real/part_0\1300.json and saving to ./distribution/tokenized/part_0\1300.tok.json
# Processing file: ./distribution/real/part_0\1310.json
# Tokenizing ./distribution/real/part_0\1310.json and saving to ./distribution/tokenized/part_0\1310.tok.json
# Processing file: ./distribution/real/part_0\1320.json
# Tokenizing ./distribution/real/part_0\1320.json and saving to ./distribution/tokenized/part_0\1320.tok.json
# Processing file: ./distribution/real/part_0\1330.json
# Tokenizing ./distribution/real/part_0\1330.json and saving to ./distribution/tokenized/part_0\1330.tok.json
# Processing file: ./distribution/real/part_0\1340.json
# Tokenizing ./distribution/real/part_0\1340.json and saving to ./distribution/tokenized/part_0\1340.tok.json
# Processing file: ./distribution/real/part_0\1350.json
# Tokenizing ./distribution/real/part_0\1350.json and saving to ./distribution/tokenized/part_0\1350.tok.json
# Processing file: ./distribution/real/part_0\1360.json
# Tokenizing ./distribution/real/part_0\1360.json and saving to ./distribution/tokenized/part_0\1360.tok.json
# Processing file: ./distribution/real/part_0\1370.json
# Tokenizing ./distribution/real/part_0\1370.json and saving to ./distribution/tokenized/part_0\1370.tok.json
# Processing file: ./distribution/real/part_0\1380.json
# Tokenizing ./distribution/real/part_0\1380.json and saving to ./distribution/tokenized/part_0\1380.tok.json
# Processing file: ./distribution/real/part_0\1390.json
# Tokenizing ./distribution/real/part_0\1390.json and saving to ./distribution/tokenized/part_0\1390.tok.json
# Processing file: ./distribution/real/part_0\1400.json
# Tokenizing ./distribution/real/part_0\1400.json and saving to ./distribution/tokenized/part_0\1400.tok.json
# Processing file: ./distribution/real/part_0\1410.json
# Tokenizing ./distribution/real/part_0\1410.json and saving to ./distribution/tokenized/part_0\1410.tok.json
# Processing file: ./distribution/real/part_0\1420.json
# Tokenizing ./distribution/real/part_0\1420.json and saving to ./distribution/tokenized/part_0\1420.tok.json
# Processing file: ./distribution/real/part_0\1430.json
# Tokenizing ./distribution/real/part_0\1430.json and saving to ./distribution/tokenized/part_0\1430.tok.json
# Processing file: ./distribution/real/part_0\1440.json
# Tokenizing ./distribution/real/part_0\1440.json and saving to ./distribution/tokenized/part_0\1440.tok.json
# Processing file: ./distribution/real/part_0\1450.json
# Tokenizing ./distribution/real/part_0\1450.json and saving to ./distribution/tokenized/part_0\1450.tok.json
# Processing file: ./distribution/real/part_0\1460.json
# Tokenizing ./distribution/real/part_0\1460.json and saving to ./distribution/tokenized/part_0\1460.tok.json
# Processing file: ./distribution/real/part_0\1470.json
# Tokenizing ./distribution/real/part_0\1470.json and saving to ./distribution/tokenized/part_0\1470.tok.json
# Processing file: ./distribution/real/part_0\1480.json
# Tokenizing ./distribution/real/part_0\1480.json and saving to ./distribution/tokenized/part_0\1480.tok.json
# Processing file: ./distribution/real/part_0\1490.json
# Tokenizing ./distribution/real/part_0\1490.json and saving to ./distribution/tokenized/part_0\1490.tok.json
# Processing file: ./distribution/real/part_0\1500.json
# Tokenizing ./distribution/real/part_0\1500.json and saving to ./distribution/tokenized/part_0\1500.tok.json
# Processing file: ./distribution/real/part_0\1510.json
# Tokenizing ./distribution/real/part_0\1510.json and saving to ./distribution/tokenized/part_0\1510.tok.json
# Processing file: ./distribution/real/part_0\1520.json
# Tokenizing ./distribution/real/part_0\1520.json and saving to ./distribution/tokenized/part_0\1520.tok.json
# Processing file: ./distribution/real/part_0\1530.json
# Tokenizing ./distribution/real/part_0\1530.json and saving to ./distribution/tokenized/part_0\1530.tok.json
# Processing file: ./distribution/real/part_0\1540.json
# Tokenizing ./distribution/real/part_0\1540.json and saving to ./distribution/tokenized/part_0\1540.tok.json
# Processing file: ./distribution/real/part_0\1550.json
# Tokenizing ./distribution/real/part_0\1550.json and saving to ./distribution/tokenized/part_0\1550.tok.json
# Processing file: ./distribution/real/part_0\1560.json
# Tokenizing ./distribution/real/part_0\1560.json and saving to ./distribution/tokenized/part_0\1560.tok.json
# Processing file: ./distribution/real/part_0\1570.json
# Tokenizing ./distribution/real/part_0\1570.json and saving to ./distribution/tokenized/part_0\1570.tok.json
# Processing file: ./distribution/real/part_0\1580.json
# Tokenizing ./distribution/real/part_0\1580.json and saving to ./distribution/tokenized/part_0\1580.tok.json
# Processing file: ./distribution/real/part_0\1590.json
# Tokenizing ./distribution/real/part_0\1590.json and saving to ./distribution/tokenized/part_0\1590.tok.json
# Processing file: ./distribution/real/part_0\1600.json
# Tokenizing ./distribution/real/part_0\1600.json and saving to ./distribution/tokenized/part_0\1600.tok.json
# Processing file: ./distribution/real/part_0\1610.json
# Tokenizing ./distribution/real/part_0\1610.json and saving to ./distribution/tokenized/part_0\1610.tok.json
# Processing file: ./distribution/real/part_0\1620.json
# Tokenizing ./distribution/real/part_0\1620.json and saving to ./distribution/tokenized/part_0\1620.tok.json
# Processing file: ./distribution/real/part_0\1630.json
# Tokenizing ./distribution/real/part_0\1630.json and saving to ./distribution/tokenized/part_0\1630.tok.json
# Processing file: ./distribution/real/part_0\1640.json
# Tokenizing ./distribution/real/part_0\1640.json and saving to ./distribution/tokenized/part_0\1640.tok.json
# Processing file: ./distribution/real/part_0\1650.json
# Tokenizing ./distribution/real/part_0\1650.json and saving to ./distribution/tokenized/part_0\1650.tok.json
# Processing file: ./distribution/real/part_0\1660.json
# Tokenizing ./distribution/real/part_0\1660.json and saving to ./distribution/tokenized/part_0\1660.tok.json
# Processing file: ./distribution/real/part_0\1670.json
# Tokenizing ./distribution/real/part_0\1670.json and saving to ./distribution/tokenized/part_0\1670.tok.json
# Processing file: ./distribution/real/part_0\1680.json
# Tokenizing ./distribution/real/part_0\1680.json and saving to ./distribution/tokenized/part_0\1680.tok.json
# Processing file: ./distribution/real/part_0\1690.json
# Tokenizing ./distribution/real/part_0\1690.json and saving to ./distribution/tokenized/part_0\1690.tok.json
# Processing file: ./distribution/real/part_0\1700.json
# Tokenizing ./distribution/real/part_0\1700.json and saving to ./distribution/tokenized/part_0\1700.tok.json
# Processing file: ./distribution/real/part_0\1710.json
# Tokenizing ./distribution/real/part_0\1710.json and saving to ./distribution/tokenized/part_0\1710.tok.json
# Processing file: ./distribution/real/part_0\1720.json
# Tokenizing ./distribution/real/part_0\1720.json and saving to ./distribution/tokenized/part_0\1720.tok.json
# Processing file: ./distribution/real/part_0\1730.json
# Tokenizing ./distribution/real/part_0\1730.json and saving to ./distribution/tokenized/part_0\1730.tok.json
# Processing file: ./distribution/real/part_0\1740.json
# Tokenizing ./distribution/real/part_0\1740.json and saving to ./distribution/tokenized/part_0\1740.tok.json
# Processing file: ./distribution/real/part_0\1750.json
# Tokenizing ./distribution/real/part_0\1750.json and saving to ./distribution/tokenized/part_0\1750.tok.json
# Processing file: ./distribution/real/part_0\1760.json
# Tokenizing ./distribution/real/part_0\1760.json and saving to ./distribution/tokenized/part_0\1760.tok.json
# Processing file: ./distribution/real/part_0\1770.json
# Tokenizing ./distribution/real/part_0\1770.json and saving to ./distribution/tokenized/part_0\1770.tok.json
# Processing file: ./distribution/real/part_0\1780.json
# Tokenizing ./distribution/real/part_0\1780.json and saving to ./distribution/tokenized/part_0\1780.tok.json
# Processing file: ./distribution/real/part_0\1790.json
# Tokenizing ./distribution/real/part_0\1790.json and saving to ./distribution/tokenized/part_0\1790.tok.json
# Processing file: ./distribution/real/part_0\1800.json
# Tokenizing ./distribution/real/part_0\1800.json and saving to ./distribution/tokenized/part_0\1800.tok.json
# Processing file: ./distribution/real/part_0\1810.json
# Tokenizing ./distribution/real/part_0\1810.json and saving to ./distribution/tokenized/part_0\1810.tok.json
# Processing file: ./distribution/real/part_0\1820.json
# Tokenizing ./distribution/real/part_0\1820.json and saving to ./distribution/tokenized/part_0\1820.tok.json
# Processing file: ./distribution/real/part_0\1830.json
# Tokenizing ./distribution/real/part_0\1830.json and saving to ./distribution/tokenized/part_0\1830.tok.json
# Processing file: ./distribution/real/part_0\1840.json
# Tokenizing ./distribution/real/part_0\1840.json and saving to ./distribution/tokenized/part_0\1840.tok.json
# Processing file: ./distribution/real/part_0\1850.json
# Tokenizing ./distribution/real/part_0\1850.json and saving to ./distribution/tokenized/part_0\1850.tok.json
# Processing file: ./distribution/real/part_0\1860.json
# Tokenizing ./distribution/real/part_0\1860.json and saving to ./distribution/tokenized/part_0\1860.tok.json
# Processing file: ./distribution/real/part_0\1870.json
# Tokenizing ./distribution/real/part_0\1870.json and saving to ./distribution/tokenized/part_0\1870.tok.json
# Processing file: ./distribution/real/part_0\1880.json
# Tokenizing ./distribution/real/part_0\1880.json and saving to ./distribution/tokenized/part_0\1880.tok.json
# Processing file: ./distribution/real/part_0\1890.json
# Tokenizing ./distribution/real/part_0\1890.json and saving to ./distribution/tokenized/part_0\1890.tok.json
# Processing file: ./distribution/real/part_0\1900.json
# Tokenizing ./distribution/real/part_0\1900.json and saving to ./distribution/tokenized/part_0\1900.tok.json
# Processing file: ./distribution/real/part_0\1910.json
# Tokenizing ./distribution/real/part_0\1910.json and saving to ./distribution/tokenized/part_0\1910.tok.json
# Processing file: ./distribution/real/part_0\1920.json
# Tokenizing ./distribution/real/part_0\1920.json and saving to ./distribution/tokenized/part_0\1920.tok.json
# Processing file: ./distribution/real/part_0\1930.json
# Tokenizing ./distribution/real/part_0\1930.json and saving to ./distribution/tokenized/part_0\1930.tok.json
# Processing file: ./distribution/real/part_0\1940.json
# Tokenizing ./distribution/real/part_0\1940.json and saving to ./distribution/tokenized/part_0\1940.tok.json
# Processing file: ./distribution/real/part_0\1950.json
# Tokenizing ./distribution/real/part_0\1950.json and saving to ./distribution/tokenized/part_0\1950.tok.json
# Processing file: ./distribution/real/part_0\1960.json
# Tokenizing ./distribution/real/part_0\1960.json and saving to ./distribution/tokenized/part_0\1960.tok.json
# Processing file: ./distribution/real/part_0\1970.json
# Tokenizing ./distribution/real/part_0\1970.json and saving to ./distribution/tokenized/part_0\1970.tok.json
# Processing file: ./distribution/real/part_0\1980.json
# Tokenizing ./distribution/real/part_0\1980.json and saving to ./distribution/tokenized/part_0\1980.tok.json
# Processing file: ./distribution/real/part_0\1990.json
# Tokenizing ./distribution/real/part_0\1990.json and saving to ./distribution/tokenized/part_0\1990.tok.json
# Processing file: ./distribution/real/part_0\2000.json
# Tokenizing ./distribution/real/part_0\2000.json and saving to ./distribution/tokenized/part_0\2000.tok.json
# Processing file: ./distribution/real/part_0\2010.json
# Tokenizing ./distribution/real/part_0\2010.json and saving to ./distribution/tokenized/part_0\2010.tok.json
# Processing file: ./distribution/real/part_0\2020.json
# Tokenizing ./distribution/real/part_0\2020.json and saving to ./distribution/tokenized/part_0\2020.tok.json
# Processing file: ./distribution/real/part_0\2030.json
# Tokenizing ./distribution/real/part_0\2030.json and saving to ./distribution/tokenized/part_0\2030.tok.json
# Processing file: ./distribution/real/part_0\2040.json
# Tokenizing ./distribution/real/part_0\2040.json and saving to ./distribution/tokenized/part_0\2040.tok.json
# Processing file: ./distribution/real/part_0\2050.json
# Tokenizing ./distribution/real/part_0\2050.json and saving to ./distribution/tokenized/part_0\2050.tok.json
# Processing file: ./distribution/real/part_0\2060.json
# Tokenizing ./distribution/real/part_0\2060.json and saving to ./distribution/tokenized/part_0\2060.tok.json
# Processing file: ./distribution/real/part_0\2070.json
# Tokenizing ./distribution/real/part_0\2070.json and saving to ./distribution/tokenized/part_0\2070.tok.json
# Processing file: ./distribution/real/part_0\2080.json
# Tokenizing ./distribution/real/part_0\2080.json and saving to ./distribution/tokenized/part_0\2080.tok.json
# Processing file: ./distribution/real/part_0\2090.json
# Tokenizing ./distribution/real/part_0\2090.json and saving to ./distribution/tokenized/part_0\2090.tok.json
# Processing file: ./distribution/real/part_0\2100.json
# Tokenizing ./distribution/real/part_0\2100.json and saving to ./distribution/tokenized/part_0\2100.tok.json
# Processing file: ./distribution/real/part_0\2110.json
# Tokenizing ./distribution/real/part_0\2110.json and saving to ./distribution/tokenized/part_0\2110.tok.json
# Processing file: ./distribution/real/part_0\2120.json
# Tokenizing ./distribution/real/part_0\2120.json and saving to ./distribution/tokenized/part_0\2120.tok.json
# Processing file: ./distribution/real/part_0\2130.json
# Tokenizing ./distribution/real/part_0\2130.json and saving to ./distribution/tokenized/part_0\2130.tok.json
# Processing file: ./distribution/real/part_0\2140.json
# Tokenizing ./distribution/real/part_0\2140.json and saving to ./distribution/tokenized/part_0\2140.tok.json
# Processing file: ./distribution/real/part_0\2150.json
# Tokenizing ./distribution/real/part_0\2150.json and saving to ./distribution/tokenized/part_0\2150.tok.json
# Processing file: ./distribution/real/part_0\2160.json
# Tokenizing ./distribution/real/part_0\2160.json and saving to ./distribution/tokenized/part_0\2160.tok.json
# Processing file: ./distribution/real/part_0\2170.json
# Tokenizing ./distribution/real/part_0\2170.json and saving to ./distribution/tokenized/part_0\2170.tok.json
# Processing file: ./distribution/real/part_0\2180.json
# Tokenizing ./distribution/real/part_0\2180.json and saving to ./distribution/tokenized/part_0\2180.tok.json
# Processing file: ./distribution/real/part_0\2190.json
# Tokenizing ./distribution/real/part_0\2190.json and saving to ./distribution/tokenized/part_0\2190.tok.json
# Processing file: ./distribution/real/part_0\2200.json
# Tokenizing ./distribution/real/part_0\2200.json and saving to ./distribution/tokenized/part_0\2200.tok.json
# Processing file: ./distribution/real/part_0\2210.json
# Tokenizing ./distribution/real/part_0\2210.json and saving to ./distribution/tokenized/part_0\2210.tok.json
# Processing file: ./distribution/real/part_0\2220.json
# Tokenizing ./distribution/real/part_0\2220.json and saving to ./distribution/tokenized/part_0\2220.tok.json
# Processing file: ./distribution/real/part_0\2230.json
# Tokenizing ./distribution/real/part_0\2230.json and saving to ./distribution/tokenized/part_0\2230.tok.json
# Processing file: ./distribution/real/part_0\2240.json
# Tokenizing ./distribution/real/part_0\2240.json and saving to ./distribution/tokenized/part_0\2240.tok.json
# Processing file: ./distribution/real/part_0\2250.json
# Tokenizing ./distribution/real/part_0\2250.json and saving to ./distribution/tokenized/part_0\2250.tok.json
# Processing file: ./distribution/real/part_0\2260.json
# Tokenizing ./distribution/real/part_0\2260.json and saving to ./distribution/tokenized/part_0\2260.tok.json
# Processing file: ./distribution/real/part_0\2270.json
# Tokenizing ./distribution/real/part_0\2270.json and saving to ./distribution/tokenized/part_0\2270.tok.json
# Processing file: ./distribution/real/part_0\2280.json
# Tokenizing ./distribution/real/part_0\2280.json and saving to ./distribution/tokenized/part_0\2280.tok.json
# Processing file: ./distribution/real/part_0\2290.json
# Tokenizing ./distribution/real/part_0\2290.json and saving to ./distribution/tokenized/part_0\2290.tok.json
# Processing file: ./distribution/real/part_0\2300.json
# Tokenizing ./distribution/real/part_0\2300.json and saving to ./distribution/tokenized/part_0\2300.tok.json
# Processing file: ./distribution/real/part_0\2310.json
# Tokenizing ./distribution/real/part_0\2310.json and saving to ./distribution/tokenized/part_0\2310.tok.json
# Processing file: ./distribution/real/part_0\2320.json
# Tokenizing ./distribution/real/part_0\2320.json and saving to ./distribution/tokenized/part_0\2320.tok.json
# Processing file: ./distribution/real/part_0\2330.json
# Tokenizing ./distribution/real/part_0\2330.json and saving to ./distribution/tokenized/part_0\2330.tok.json
# Processing file: ./distribution/real/part_0\2340.json
# Tokenizing ./distribution/real/part_0\2340.json and saving to ./distribution/tokenized/part_0\2340.tok.json
# Processing file: ./distribution/real/part_0\2350.json
# Tokenizing ./distribution/real/part_0\2350.json and saving to ./distribution/tokenized/part_0\2350.tok.json
# Processing file: ./distribution/real/part_0\2360.json
# Tokenizing ./distribution/real/part_0\2360.json and saving to ./distribution/tokenized/part_0\2360.tok.json
# Processing file: ./distribution/real/part_0\2370.json
# Tokenizing ./distribution/real/part_0\2370.json and saving to ./distribution/tokenized/part_0\2370.tok.json
# Processing file: ./distribution/real/part_0\2380.json
# Tokenizing ./distribution/real/part_0\2380.json and saving to ./distribution/tokenized/part_0\2380.tok.json
# Processing file: ./distribution/real/part_0\2390.json
# Tokenizing ./distribution/real/part_0\2390.json and saving to ./distribution/tokenized/part_0\2390.tok.json
# Processing file: ./distribution/real/part_0\2400.json
# Tokenizing ./distribution/real/part_0\2400.json and saving to ./distribution/tokenized/part_0\2400.tok.json
# Processing file: ./distribution/real/part_0\2410.json
# Tokenizing ./distribution/real/part_0\2410.json and saving to ./distribution/tokenized/part_0\2410.tok.json
# Processing file: ./distribution/real/part_0\2420.json
# Tokenizing ./distribution/real/part_0\2420.json and saving to ./distribution/tokenized/part_0\2420.tok.json
# Processing file: ./distribution/real/part_0\2430.json
# Tokenizing ./distribution/real/part_0\2430.json and saving to ./distribution/tokenized/part_0\2430.tok.json
# Processing file: ./distribution/real/part_0\2440.json
# Tokenizing ./distribution/real/part_0\2440.json and saving to ./distribution/tokenized/part_0\2440.tok.json
# Processing file: ./distribution/real/part_0\2450.json
# Tokenizing ./distribution/real/part_0\2450.json and saving to ./distribution/tokenized/part_0\2450.tok.json
# Processing file: ./distribution/real/part_0\2460.json
# Tokenizing ./distribution/real/part_0\2460.json and saving to ./distribution/tokenized/part_0\2460.tok.json
# Processing file: ./distribution/real/part_0\2470.json
# Tokenizing ./distribution/real/part_0\2470.json and saving to ./distribution/tokenized/part_0\2470.tok.json
# Processing file: ./distribution/real/part_0\2480.json
# Tokenizing ./distribution/real/part_0\2480.json and saving to ./distribution/tokenized/part_0\2480.tok.json
# Processing file: ./distribution/real/part_0\2490.json
# Tokenizing ./distribution/real/part_0\2490.json and saving to ./distribution/tokenized/part_0\2490.tok.json
# Processing file: ./distribution/real/part_0\2500.json
# Tokenizing ./distribution/real/part_0\2500.json and saving to ./distribution/tokenized/part_0\2500.tok.json
# Processing file: ./distribution/real/part_0\2510.json
# Tokenizing ./distribution/real/part_0\2510.json and saving to ./distribution/tokenized/part_0\2510.tok.json
# Processing file: ./distribution/real/part_0\2520.json
# Tokenizing ./distribution/real/part_0\2520.json and saving to ./distribution/tokenized/part_0\2520.tok.json
# Processing file: ./distribution/real/part_0\2530.json
# Tokenizing ./distribution/real/part_0\2530.json and saving to ./distribution/tokenized/part_0\2530.tok.json
# Processing file: ./distribution/real/part_0\2540.json
# Tokenizing ./distribution/real/part_0\2540.json and saving to ./distribution/tokenized/part_0\2540.tok.json
# Processing file: ./distribution/real/part_0\2550.json
# Tokenizing ./distribution/real/part_0\2550.json and saving to ./distribution/tokenized/part_0\2550.tok.json
# Processing file: ./distribution/real/part_0\2560.json
# Tokenizing ./distribution/real/part_0\2560.json and saving to ./distribution/tokenized/part_0\2560.tok.json
# Processing file: ./distribution/real/part_0\2570.json
# Tokenizing ./distribution/real/part_0\2570.json and saving to ./distribution/tokenized/part_0\2570.tok.json
# Processing file: ./distribution/real/part_0\2580.json
# Tokenizing ./distribution/real/part_0\2580.json and saving to ./distribution/tokenized/part_0\2580.tok.json
# Processing file: ./distribution/real/part_0\2590.json
# Tokenizing ./distribution/real/part_0\2590.json and saving to ./distribution/tokenized/part_0\2590.tok.json
# Processing file: ./distribution/real/part_0\2600.json
# Tokenizing ./distribution/real/part_0\2600.json and saving to ./distribution/tokenized/part_0\2600.tok.json
# Processing file: ./distribution/real/part_0\2610.json
# Tokenizing ./distribution/real/part_0\2610.json and saving to ./distribution/tokenized/part_0\2610.tok.json
# Processing file: ./distribution/real/part_0\2620.json
# Tokenizing ./distribution/real/part_0\2620.json and saving to ./distribution/tokenized/part_0\2620.tok.json
# Processing file: ./distribution/real/part_0\2630.json
# Tokenizing ./distribution/real/part_0\2630.json and saving to ./distribution/tokenized/part_0\2630.tok.json
# Processing file: ./distribution/real/part_0\2640.json
# Tokenizing ./distribution/real/part_0\2640.json and saving to ./distribution/tokenized/part_0\2640.tok.json
# Processing file: ./distribution/real/part_0\2650.json
# Tokenizing ./distribution/real/part_0\2650.json and saving to ./distribution/tokenized/part_0\2650.tok.json
# Processing file: ./distribution/real/part_0\2660.json
# Tokenizing ./distribution/real/part_0\2660.json and saving to ./distribution/tokenized/part_0\2660.tok.json
# Processing file: ./distribution/real/part_0\2670.json
# Tokenizing ./distribution/real/part_0\2670.json and saving to ./distribution/tokenized/part_0\2670.tok.json
# Processing file: ./distribution/real/part_0\2680.json
# Tokenizing ./distribution/real/part_0\2680.json and saving to ./distribution/tokenized/part_0\2680.tok.json
# Processing file: ./distribution/real/part_0\2690.json
# Tokenizing ./distribution/real/part_0\2690.json and saving to ./distribution/tokenized/part_0\2690.tok.json
# Processing file: ./distribution/real/part_0\2700.json
# Tokenizing ./distribution/real/part_0\2700.json and saving to ./distribution/tokenized/part_0\2700.tok.json
# Processing file: ./distribution/real/part_0\2710.json
# Tokenizing ./distribution/real/part_0\2710.json and saving to ./distribution/tokenized/part_0\2710.tok.json
# Processing file: ./distribution/real/part_0\2720.json
# Tokenizing ./distribution/real/part_0\2720.json and saving to ./distribution/tokenized/part_0\2720.tok.json
# Processing file: ./distribution/real/part_0\2730.json
# Tokenizing ./distribution/real/part_0\2730.json and saving to ./distribution/tokenized/part_0\2730.tok.json
# Processing file: ./distribution/real/part_0\2740.json
# Tokenizing ./distribution/real/part_0\2740.json and saving to ./distribution/tokenized/part_0\2740.tok.json
# Processing file: ./distribution/real/part_0\2750.json
# Tokenizing ./distribution/real/part_0\2750.json and saving to ./distribution/tokenized/part_0\2750.tok.json
# Processing file: ./distribution/real/part_0\2760.json
# Tokenizing ./distribution/real/part_0\2760.json and saving to ./distribution/tokenized/part_0\2760.tok.json
# Processing file: ./distribution/real/part_0\2770.json
# Tokenizing ./distribution/real/part_0\2770.json and saving to ./distribution/tokenized/part_0\2770.tok.json
# Processing file: ./distribution/real/part_0\2780.json
# Tokenizing ./distribution/real/part_0\2780.json and saving to ./distribution/tokenized/part_0\2780.tok.json
# Processing file: ./distribution/real/part_0\2790.json
# Tokenizing ./distribution/real/part_0\2790.json and saving to ./distribution/tokenized/part_0\2790.tok.json
# Processing file: ./distribution/real/part_0\2800.json
# Tokenizing ./distribution/real/part_0\2800.json and saving to ./distribution/tokenized/part_0\2800.tok.json
# Processing file: ./distribution/real/part_0\2810.json
# Tokenizing ./distribution/real/part_0\2810.json and saving to ./distribution/tokenized/part_0\2810.tok.json
# Processing file: ./distribution/real/part_0\2820.json
# Tokenizing ./distribution/real/part_0\2820.json and saving to ./distribution/tokenized/part_0\2820.tok.json
# Processing file: ./distribution/real/part_0\2830.json
# Tokenizing ./distribution/real/part_0\2830.json and saving to ./distribution/tokenized/part_0\2830.tok.json
# Processing file: ./distribution/real/part_0\2840.json
# Tokenizing ./distribution/real/part_0\2840.json and saving to ./distribution/tokenized/part_0\2840.tok.json
# Processing file: ./distribution/real/part_0\2850.json
# Tokenizing ./distribution/real/part_0\2850.json and saving to ./distribution/tokenized/part_0\2850.tok.json
# Processing file: ./distribution/real/part_0\2860.json
# Tokenizing ./distribution/real/part_0\2860.json and saving to ./distribution/tokenized/part_0\2860.tok.json
# Processing file: ./distribution/real/part_0\2870.json
# Tokenizing ./distribution/real/part_0\2870.json and saving to ./distribution/tokenized/part_0\2870.tok.json
# Processing file: ./distribution/real/part_0\2880.json
# Tokenizing ./distribution/real/part_0\2880.json and saving to ./distribution/tokenized/part_0\2880.tok.json
# Processing file: ./distribution/real/part_0\2890.json
# Tokenizing ./distribution/real/part_0\2890.json and saving to ./distribution/tokenized/part_0\2890.tok.json
# Processing file: ./distribution/real/part_0\2900.json
# Tokenizing ./distribution/real/part_0\2900.json and saving to ./distribution/tokenized/part_0\2900.tok.json
# Processing file: ./distribution/real/part_0\2910.json
# Tokenizing ./distribution/real/part_0\2910.json and saving to ./distribution/tokenized/part_0\2910.tok.json
# Processing file: ./distribution/real/part_0\2920.json
# Tokenizing ./distribution/real/part_0\2920.json and saving to ./distribution/tokenized/part_0\2920.tok.json
# Processing file: ./distribution/real/part_0\2930.json
# Tokenizing ./distribution/real/part_0\2930.json and saving to ./distribution/tokenized/part_0\2930.tok.json
# Processing file: ./distribution/real/part_0\2940.json
# Tokenizing ./distribution/real/part_0\2940.json and saving to ./distribution/tokenized/part_0\2940.tok.json
# Processing file: ./distribution/real/part_0\2950.json
# Tokenizing ./distribution/real/part_0\2950.json and saving to ./distribution/tokenized/part_0\2950.tok.json
# ...
# Tokenizing ./distribution/real/part_9\2609.json and saving to ./distribution/tokenized/part_9\2609.tok.json
# Processing file: ./distribution/real/part_9\2619.json
# Tokenizing ./distribution/real/part_9\2619.json and saving to ./distribution/tokenized/part_9\2619.tok.json
# Processing file: ./distribution/real/part_9\2629.json
# Tokenizing ./distribution/real/part_9\2629.json and saving to ./distribution/tokenized/part_9\2629.tok.json
# Processing file: ./distribution/real/part_9\2639.json
# Tokenizing ./distribution/real/part_9\2639.json and saving to ./distribution/tokenized/part_9\2639.tok.json
# Processing file: ./distribution/real/part_9\2649.json
# Tokenizing ./distribution/real/part_9\2649.json and saving to ./distribution/tokenized/part_9\2649.tok.json
# Processing file: ./distribution/real/part_9\2659.json
# Tokenizing ./distribution/real/part_9\2659.json and saving to ./distribution/tokenized/part_9\2659.tok.json
# Processing file: ./distribution/real/part_9\2669.json
# Tokenizing ./distribution/real/part_9\2669.json and saving to ./distribution/tokenized/part_9\2669.tok.json
# Processing file: ./distribution/real/part_9\2679.json
# Tokenizing ./distribution/real/part_9\2679.json and saving to ./distribution/tokenized/part_9\2679.tok.json
# Processing file: ./distribution/real/part_9\2689.json
# Tokenizing ./distribution/real/part_9\2689.json and saving to ./distribution/tokenized/part_9\2689.tok.json
# Processing file: ./distribution/real/part_9\2699.json
# Tokenizing ./distribution/real/part_9\2699.json and saving to ./distribution/tokenized/part_9\2699.tok.json
# Processing file: ./distribution/real/part_9\2709.json
# Tokenizing ./distribution/real/part_9\2709.json and saving to ./distribution/tokenized/part_9\2709.tok.json
# Processing file: ./distribution/real/part_9\2719.json
# Tokenizing ./distribution/real/part_9\2719.json and saving to ./distribution/tokenized/part_9\2719.tok.json
# Processing file: ./distribution/real/part_9\2729.json
# Tokenizing ./distribution/real/part_9\2729.json and saving to ./distribution/tokenized/part_9\2729.tok.json
# Processing file: ./distribution/real/part_9\2739.json
# Tokenizing ./distribution/real/part_9\2739.json and saving to ./distribution/tokenized/part_9\2739.tok.json
# Processing file: ./distribution/real/part_9\2749.json
# Tokenizing ./distribution/real/part_9\2749.json and saving to ./distribution/tokenized/part_9\2749.tok.json
# Processing file: ./distribution/real/part_9\2759.json
# Tokenizing ./distribution/real/part_9\2759.json and saving to ./distribution/tokenized/part_9\2759.tok.json
# Processing file: ./distribution/real/part_9\2769.json
# Tokenizing ./distribution/real/part_9\2769.json and saving to ./distribution/tokenized/part_9\2769.tok.json
# Processing file: ./distribution/real/part_9\2779.json
# Tokenizing ./distribution/real/part_9\2779.json and saving to ./distribution/tokenized/part_9\2779.tok.json
# Processing file: ./distribution/real/part_9\2789.json
# Tokenizing ./distribution/real/part_9\2789.json and saving to ./distribution/tokenized/part_9\2789.tok.json
# Processing file: ./distribution/real/part_9\2799.json
# Tokenizing ./distribution/real/part_9\2799.json and saving to ./distribution/tokenized/part_9\2799.tok.json
# Processing file: ./distribution/real/part_9\2809.json
# Tokenizing ./distribution/real/part_9\2809.json and saving to ./distribution/tokenized/part_9\2809.tok.json
# Processing file: ./distribution/real/part_9\2819.json
# Tokenizing ./distribution/real/part_9\2819.json and saving to ./distribution/tokenized/part_9\2819.tok.json
# Processing file: ./distribution/real/part_9\2829.json
# Tokenizing ./distribution/real/part_9\2829.json and saving to ./distribution/tokenized/part_9\2829.tok.json
# Processing file: ./distribution/real/part_9\2839.json
# Tokenizing ./distribution/real/part_9\2839.json and saving to ./distribution/tokenized/part_9\2839.tok.json
# Processing file: ./distribution/real/part_9\2849.json
# Tokenizing ./distribution/real/part_9\2849.json and saving to ./distribution/tokenized/part_9\2849.tok.json
# Processing file: ./distribution/real/part_9\2859.json
# Tokenizing ./distribution/real/part_9\2859.json and saving to ./distribution/tokenized/part_9\2859.tok.json
# Processing file: ./distribution/real/part_9\2869.json
# Tokenizing ./distribution/real/part_9\2869.json and saving to ./distribution/tokenized/part_9\2869.tok.json
# Processing file: ./distribution/real/part_9\2879.json
# Tokenizing ./distribution/real/part_9\2879.json and saving to ./distribution/tokenized/part_9\2879.tok.json
# Processing file: ./distribution/real/part_9\2889.json
# Tokenizing ./distribution/real/part_9\2889.json and saving to ./distribution/tokenized/part_9\2889.tok.json
# Processing file: ./distribution/real/part_9\2899.json
# Tokenizing ./distribution/real/part_9\2899.json and saving to ./distribution/tokenized/part_9\2899.tok.json
# Processing file: ./distribution/real/part_9\2909.json
# Tokenizing ./distribution/real/part_9\2909.json and saving to ./distribution/tokenized/part_9\2909.tok.json
# Processing file: ./distribution/real/part_9\2919.json
# Tokenizing ./distribution/real/part_9\2919.json and saving to ./distribution/tokenized/part_9\2919.tok.json
# Processing file: ./distribution/real/part_9\2929.json
# Tokenizing ./distribution/real/part_9\2929.json and saving to ./distribution/tokenized/part_9\2929.tok.json
# Processing file: ./distribution/real/part_9\2939.json
# Tokenizing ./distribution/real/part_9\2939.json and saving to ./distribution/tokenized/part_9\2939.tok.json
# Processing file: ./distribution/real/part_9\2949.json
# Tokenizing ./distribution/real/part_9\2949.json and saving to ./distribution/tokenized/part_9\2949.tok.json
# Processing file: ./distribution/real/part_9\2959.json
# Tokenizing ./distribution/real/part_9\2959.json and saving to ./distribution/tokenized/part_9\2959.tok.json
# Processing file: ./distribution/real/part_9\2969.json
# Tokenizing ./distribution/real/part_9\2969.json and saving to ./distribution/tokenized/part_9\2969.tok.json
# Processing file: ./distribution/real/part_9\2979.json
# Tokenizing ./distribution/real/part_9\2979.json and saving to ./distribution/tokenized/part_9\2979.tok.json
# Processing file: ./distribution/real/part_9\2989.json
# Tokenizing ./distribution/real/part_9\2989.json and saving to ./distribution/tokenized/part_9\2989.tok.json
# Processing file: ./distribution/real/part_9\2999.json
# Tokenizing ./distribution/real/part_9\2999.json and saving to ./distribution/tokenized/part_9\2999.tok.json
# Processing file: ./distribution/real/part_9\3009.json
# Tokenizing ./distribution/real/part_9\3009.json and saving to ./distribution/tokenized/part_9\3009.tok.json
# Processing file: ./distribution/real/part_9\3019.json
# Tokenizing ./distribution/real/part_9\3019.json and saving to ./distribution/tokenized/part_9\3019.tok.json
# Processing file: ./distribution/real/part_9\3029.json
# Tokenizing ./distribution/real/part_9\3029.json and saving to ./distribution/tokenized/part_9\3029.tok.json
# Processing file: ./distribution/real/part_9\3039.json
# Tokenizing ./distribution/real/part_9\3039.json and saving to ./distribution/tokenized/part_9\3039.tok.json
# Processing file: ./distribution/real/part_9\3049.json
# Tokenizing ./distribution/real/part_9\3049.json and saving to ./distribution/tokenized/part_9\3049.tok.json
# Processing file: ./distribution/real/part_9\3059.json
# Tokenizing ./distribution/real/part_9\3059.json and saving to ./distribution/tokenized/part_9\3059.tok.json
# Processing file: ./distribution/real/part_9\3069.json
# Tokenizing ./distribution/real/part_9\3069.json and saving to ./distribution/tokenized/part_9\3069.tok.json
# Processing file: ./distribution/real/part_9\3079.json
# Tokenizing ./distribution/real/part_9\3079.json and saving to ./distribution/tokenized/part_9\3079.tok.json
# Processing file: ./distribution/real/part_9\3089.json
# Tokenizing ./distribution/real/part_9\3089.json and saving to ./distribution/tokenized/part_9\3089.tok.json
# Processing file: ./distribution/real/part_9\3099.json
# Tokenizing ./distribution/real/part_9\3099.json and saving to ./distribution/tokenized/part_9\3099.tok.json
# Processing file: ./distribution/real/part_9\3109.json
# Tokenizing ./distribution/real/part_9\3109.json and saving to ./distribution/tokenized/part_9\3109.tok.json
# Processing file: ./distribution/real/part_9\3119.json
# Tokenizing ./distribution/real/part_9\3119.json and saving to ./distribution/tokenized/part_9\3119.tok.json
# Processing file: ./distribution/real/part_9\3129.json
# Tokenizing ./distribution/real/part_9\3129.json and saving to ./distribution/tokenized/part_9\3129.tok.json
# Processing file: ./distribution/real/part_9\3139.json
# Tokenizing ./distribution/real/part_9\3139.json and saving to ./distribution/tokenized/part_9\3139.tok.json
# Processing file: ./distribution/real/part_9\3149.json
# Tokenizing ./distribution/real/part_9\3149.json and saving to ./distribution/tokenized/part_9\3149.tok.json
# Processing file: ./distribution/real/part_9\3159.json
# Tokenizing ./distribution/real/part_9\3159.json and saving to ./distribution/tokenized/part_9\3159.tok.json
# Processing file: ./distribution/real/part_9\3169.json
# Tokenizing ./distribution/real/part_9\3169.json and saving to ./distribution/tokenized/part_9\3169.tok.json
# Processing file: ./distribution/real/part_9\3179.json
# Tokenizing ./distribution/real/part_9\3179.json and saving to ./distribution/tokenized/part_9\3179.tok.json
# Processing file: ./distribution/real/part_9\3189.json
# Tokenizing ./distribution/real/part_9\3189.json and saving to ./distribution/tokenized/part_9\3189.tok.json
# Processing file: ./distribution/real/part_9\3199.json
# Tokenizing ./distribution/real/part_9\3199.json and saving to ./distribution/tokenized/part_9\3199.tok.json
# Processing file: ./distribution/real/part_9\3209.json
# Tokenizing ./distribution/real/part_9\3209.json and saving to ./distribution/tokenized/part_9\3209.tok.json
# Processing file: ./distribution/real/part_9\3219.json
# Tokenizing ./distribution/real/part_9\3219.json and saving to ./distribution/tokenized/part_9\3219.tok.json
# Processing file: ./distribution/real/part_9\3229.json
# Tokenizing ./distribution/real/part_9\3229.json and saving to ./distribution/tokenized/part_9\3229.tok.json
# Processing file: ./distribution/real/part_9\3239.json
# Tokenizing ./distribution/real/part_9\3239.json and saving to ./distribution/tokenized/part_9\3239.tok.json
# Processing file: ./distribution/real/part_9\3249.json
# Tokenizing ./distribution/real/part_9\3249.json and saving to ./distribution/tokenized/part_9\3249.tok.json
# Processing file: ./distribution/real/part_9\3259.json
# Tokenizing ./distribution/real/part_9\3259.json and saving to ./distribution/tokenized/part_9\3259.tok.json
# Processing file: ./distribution/real/part_9\3269.json
# Tokenizing ./distribution/real/part_9\3269.json and saving to ./distribution/tokenized/part_9\3269.tok.json
# Processing file: ./distribution/real/part_9\3279.json
# Tokenizing ./distribution/real/part_9\3279.json and saving to ./distribution/tokenized/part_9\3279.tok.json
# Processing file: ./distribution/real/part_9\3289.json
# Tokenizing ./distribution/real/part_9\3289.json and saving to ./distribution/tokenized/part_9\3289.tok.json
# Processing file: ./distribution/real/part_9\3299.json
# Tokenizing ./distribution/real/part_9\3299.json and saving to ./distribution/tokenized/part_9\3299.tok.json
# Processing file: ./distribution/real/part_9\3309.json
# Tokenizing ./distribution/real/part_9\3309.json and saving to ./distribution/tokenized/part_9\3309.tok.json
# Processing file: ./distribution/real/part_9\3319.json
# Tokenizing ./distribution/real/part_9\3319.json and saving to ./distribution/tokenized/part_9\3319.tok.json
# Processing file: ./distribution/real/part_9\3329.json
# Tokenizing ./distribution/real/part_9\3329.json and saving to ./distribution/tokenized/part_9\3329.tok.json
# Processing file: ./distribution/real/part_9\3339.json
# Tokenizing ./distribution/real/part_9\3339.json and saving to ./distribution/tokenized/part_9\3339.tok.json
# Processing file: ./distribution/real/part_9\3349.json
# Tokenizing ./distribution/real/part_9\3349.json and saving to ./distribution/tokenized/part_9\3349.tok.json
# Processing file: ./distribution/real/part_9\3359.json
# Tokenizing ./distribution/real/part_9\3359.json and saving to ./distribution/tokenized/part_9\3359.tok.json
# Processing file: ./distribution/real/part_9\3369.json
# Tokenizing ./distribution/real/part_9\3369.json and saving to ./distribution/tokenized/part_9\3369.tok.json
# Processing file: ./distribution/real/part_9\3379.json
# Tokenizing ./distribution/real/part_9\3379.json and saving to ./distribution/tokenized/part_9\3379.tok.json
# Processing file: ./distribution/real/part_9\3389.json
# Tokenizing ./distribution/real/part_9\3389.json and saving to ./distribution/tokenized/part_9\3389.tok.json
# Processing file: ./distribution/real/part_9\3399.json
# Tokenizing ./distribution/real/part_9\3399.json and saving to ./distribution/tokenized/part_9\3399.tok.json
# Processing file: ./distribution/real/part_9\3409.json
# Tokenizing ./distribution/real/part_9\3409.json and saving to ./distribution/tokenized/part_9\3409.tok.json
# Processing file: ./distribution/real/part_9\3419.json
# Tokenizing ./distribution/real/part_9\3419.json and saving to ./distribution/tokenized/part_9\3419.tok.json
# Processing file: ./distribution/real/part_9\3429.json
# Tokenizing ./distribution/real/part_9\3429.json and saving to ./distribution/tokenized/part_9\3429.tok.json
# Processing file: ./distribution/real/part_9\3439.json
# Tokenizing ./distribution/real/part_9\3439.json and saving to ./distribution/tokenized/part_9\3439.tok.json
# Processing file: ./distribution/real/part_9\3449.json
# Tokenizing ./distribution/real/part_9\3449.json and saving to ./distribution/tokenized/part_9\3449.tok.json
# Processing file: ./distribution/real/part_9\3459.json
# Tokenizing ./distribution/real/part_9\3459.json and saving to ./distribution/tokenized/part_9\3459.tok.json
# Processing file: ./distribution/real/part_9\3469.json
# Tokenizing ./distribution/real/part_9\3469.json and saving to ./distribution/tokenized/part_9\3469.tok.json
# Processing file: ./distribution/real/part_9\3479.json
# Tokenizing ./distribution/real/part_9\3479.json and saving to ./distribution/tokenized/part_9\3479.tok.json
# Processing file: ./distribution/real/part_9\3489.json
# Tokenizing ./distribution/real/part_9\3489.json and saving to ./distribution/tokenized/part_9\3489.tok.json
# Processing file: ./distribution/real/part_9\3499.json
# Tokenizing ./distribution/real/part_9\3499.json and saving to ./distribution/tokenized/part_9\3499.tok.json
# Processing file: ./distribution/real/part_9\3509.json
# Tokenizing ./distribution/real/part_9\3509.json and saving to ./distribution/tokenized/part_9\3509.tok.json
# Processing file: ./distribution/real/part_9\3519.json
# Tokenizing ./distribution/real/part_9\3519.json and saving to ./distribution/tokenized/part_9\3519.tok.json
# Processing file: ./distribution/real/part_9\3529.json
# Tokenizing ./distribution/real/part_9\3529.json and saving to ./distribution/tokenized/part_9\3529.tok.json
# Processing file: ./distribution/real/part_9\3539.json
# Tokenizing ./distribution/real/part_9\3539.json and saving to ./distribution/tokenized/part_9\3539.tok.json
# Processing file: ./distribution/real/part_9\3549.json
# Tokenizing ./distribution/real/part_9\3549.json and saving to ./distribution/tokenized/part_9\3549.tok.json
# Processing file: ./distribution/real/part_9\3559.json
# Tokenizing ./distribution/real/part_9\3559.json and saving to ./distribution/tokenized/part_9\3559.tok.json
# Processing file: ./distribution/real/part_9\3569.json
# Tokenizing ./distribution/real/part_9\3569.json and saving to ./distribution/tokenized/part_9\3569.tok.json
# Processing file: ./distribution/real/part_9\3579.json
# Tokenizing ./distribution/real/part_9\3579.json and saving to ./distribution/tokenized/part_9\3579.tok.json
# Processing file: ./distribution/real/part_9\3589.json
# Tokenizing ./distribution/real/part_9\3589.json and saving to ./distribution/tokenized/part_9\3589.tok.json

# %%
'''#delete all .tok.json files in the distribution folder
for file in walk_directory("./distribution"):
    if file.endswith(".tok.json"):
        os.remove(file)
        print(f"Removed {file}")'''
# Out:
# '#delete all .tok.json files in the distribution folder\nfor file in walk_directory("./distribution"):\n    if file.endswith(".tok.json"):\n        os.remove(file)\n        print(f"Removed {file}")'
